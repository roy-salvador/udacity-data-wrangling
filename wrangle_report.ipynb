# %% [markdown]
# <h1><center>Udacity Project: <br /> Wrangle and Analyze Data</center><h1>
# <h2><center>Data Wrangling Report <br/> Roy Amante A. Salvador</center></h2>
#
# <br/>
#
# # I. Data Gathering
#
# We collect our data from three different sources.

# %% [markdown]
# <!-- Table of issues -->
# <table align="left">
#     <tr>
#         <td style="text-align:left"><h4> Data </h4></td>
#         <td style="text-align:left"><h4> Format </h4></td>
#         <td style="text-align:left"><h4> Notes </h4></td>
#     </tr>
#     <tr>
#         <td style="text-align:left"><a href="https://twitter.com/dog_rates?ref_src=twsrc%5Egoogle%7Ctwcamp%5Eserp%7Ctwgr%5Eauthor">WeRateDogs</a> Archived Tweets</td>
#         <td style="text-align:left">csv</td>
#         <td style="text-align:left">Our primary data. In the real world, this represents data on hand which is readily available to us.</td>
#     </tr>
#     <tr>
#         <td style="text-align:left"><a href="https://d17h27t6h515a5.cloudfront.net/topher/2017/August/599fd2ad_image-predictions/image-predictions.tsv">Tweet Image Predictions</a></td>
#         <td style="text-align:left">tsv</td>
#         <td style="text-align:left">Downloaded from Udacity online storage. Machine learning solution for filling in missing information (breed).</td>
#     </tr>
#     <tr>
#         <td style="text-align:left">Extended Tweet Records</td>
#         <td style="text-align:left">json</td>
#         <td style="text-align:left">Supplementary data sourced from Twitter API using own account.</td>
#     </tr>
# </table>

# %% [markdown]
#
# # II. Data Assessment and Cleaning
# Below is a summary table of the issues found during assessment of our primary data and the corresponding action(s) taken. They are addressed in the order they are listed below. The list is not meant to exhaust all possible data issues. We've only identified enough for us to be able to carry out our Data Analysis more correctly and conveniently.

# %% [markdown]
# <!-- Table of issues -->
# <table align="left">
#     <tr>
#         <td style="text-align:left"><h4> Issue </h4></td>
#         <td style="text-align:left"><h4> Action(s) Taken </h4></td>
#     </tr>
#     <!-- Completeness-->
#     <tr>
#         <td style="text-align:left"><b>Completeness</b></td>
#         <td></td>
#     </tr>
#     <tr>
#         <td style="text-align:left">1. Some records don't have corresponding images &nbsp;&nbsp;&nbsp;&nbsp;</td>
#         <td style="text-align:left"> Dropped records with no corresponding images.</td>
#     </tr>
#     <tr>
#         <td style="text-align:left">2. There is no information on the breed of the dog in the tweet. &nbsp;&nbsp;&nbsp;&nbsp;</td>
#         <td style="text-align:left">Created and set breed field to the highest dog breed prediction in Tweet Image predictions.</td>
#     </tr>
#     <tr>
#         <td style="text-align:left">3. Missing other statistical fields for analysis like retweet and favorite count &nbsp;&nbsp;&nbsp;&nbsp;</td>
#         <td style="text-align:left">Extracted the two fields from the json data we got from Twitter API. <br/> Merged them with our master data.</td>
#     </tr>
#     <!-- Validity -->
#     <tr>
#         <td style="text-align:left"><b>Validity</b></td>
#         <td></td>
#     </tr>
#     <tr>
#         <td style="text-align:left">4. Some records are actually not original tweets (retweets) &nbsp;&nbsp;&nbsp;&nbsp;</td>
#         <td style="text-align:left">Dropped records that are tagged as retweets.</td>
#     </tr>
#     <tr>
#         <td style="text-align:left">5. There is a rating with <i>rating_denominator</i> of zero &nbsp;&nbsp;&nbsp;&nbsp;</td>
#         <td style="text-align:left">Dropped records with non-positive rating denominators.</td>
#     </tr>
#     <tr>
#         <td style="text-align:left">6. The <i>floofer</i> field is of type string but should be boolean - whether dog is floofy (fluffy) or not. &nbsp;&nbsp;&nbsp;&nbsp;</td>
#         <td style="text-align:left">Converted the floofer field type from string to boolean by assigning <i>False</i> if the string values is 'None' otherwise <i>True</i>.</td>
#     </tr>
#     <tr>
#         <td style="text-align:left">7. Some tweets have images but are not dog images. &nbsp;&nbsp;&nbsp;&nbsp;</td>
#         <td style="text-align:left">Dropped records without predicted dog breed. i.e. if field value in #2 is null.</td>
#     </tr>
#     <!-- Accuracy -->
#     <tr>
#         <td style="text-align:left"><b>Accuracy</b></td>
#         <td></td>
#     </tr>
#     <tr>
#         <td style="text-align:left">8. There are <i>name</i> values that are not actual names (e.g. <i>such</i>) and these are not capitalized. &nbsp;&nbsp;&nbsp;&nbsp;</td>
#         <td style="text-align:left">Replaced <i>name</i> values which start with lower case with the <i>'None'</i> string. </td>
#     </tr>
#     <tr>
#         <td style="text-align:left">9. Some records are incorrectly tagged with more than one dog stage. &nbsp;&nbsp;&nbsp;&nbsp;</td>
#         <td style="text-align:left">Examined the text and url of records with more than one dog stage (less than 10 at this point). <br/> Determined manually correct dog stage and set the values appropriately for <i>pupper</i>, <i>puppo</i> and <i>doggo</i> fields.</td>
#     </tr>
#     <tr>
#         <td style="text-align:left">10. Some tweets with floofy (fluffy) dogs are not tagged as floofer. &nbsp;&nbsp;&nbsp;&nbsp;</td>
#         <td style="text-align:left">Relaxed criteria for tagging <i>floofer</i> based on tweet text. <br /> Set to <i>floofer</i> if text contained <i>floof</i> and <i>fluff</i> instead of just <i>floofer</i>.</td>
#     </tr>
#     <tr>
#         <td style="text-align:left">11. Some ratings are parsed incorrectly. &nbsp;&nbsp;&nbsp;&nbsp;</td>
#         <td style="text-align:left">Reparsed numerator and denominator ratings such that it allows decimal values for numerator. <br /> Extract the occurrence matching the rating format nearest to the end of the text. <br/> Dropped a record with no intended rating based on the text.</td>
#     </tr>
#     <!-- Consistency -->
#     <tr>
#         <td style="text-align:left"><b>Consistency</b></td>
#         <td></td>
#     </tr>
#     <tr>
#         <td style="text-align:left">12. Representation of ratings is not standard since there are different denominators.
#         <td style="text-align:left">Created a normalized rating field by dividing the numerator and denominator ratings.</td>
#     </tr>
#     <!-- Data Tidiness -->
#     <tr>
#         <td style="text-align:left"><b>Tidiness</b></td>
#         <td></td>
#     </tr>
#     <tr>
#         <td style="text-align:left">13. The <i>text</i> column contains more than one variable - text and shortened urls.
#         <td style="text-align:left">Scrubbed out the shortened urls in the text. <br /> Discard the shortened url since we already have expanded urls. </td>
#     </tr>
#     <tr>
#         <td style="text-align:left">14. Three columns are present for variable dog stage - <i>pupper</i>, <i>puppo</i> and <i>doggo</i>
#         <td style="text-align:left">Created a single column for dog stage and populate based on the values in <i>pupper</i>, <i>puppo</i> and <i>doggo</i>.  </td>
#     </tr>
#     <tr>
#         <td style="text-align:left">15. There are unnecessary columns. </td>
#         <td style="text-align:left">Dropped columns no longer relevant for Data Analysis - Reply-related, Retweet-related and old dog stage fields.
#     </tr>
# </table>

# %% [markdown]
# Resulting cleaned dataframe is saved to `twitter_archive_master.csv`.
